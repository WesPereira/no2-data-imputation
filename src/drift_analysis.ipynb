# %%
import logging

import pandas as pd
import numpy as np
from evidently.report import Report
from evidently.metric_preset import DataDriftPreset, TargetDriftPreset
from torch.utils.data import DataLoader

from src.models.dataset import MultiTSDataset

# %%
logging.basicConfig(datefmt='%d-%b-%y %H:%M:%S', level=logging.INFO,
                    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s')

# %%
df = pd.read_csv('data/processed/gee_ds_20231003_temporal_drift_analysis/mapped_paths.csv')
df.head()
# Out:
#                                             no2_path
# 0  ../../data/processed/gee_ds_20231003_temporal_...  \
# 1  ../../data/processed/gee_ds_20231003_temporal_...
# 2  ../../data/processed/gee_ds_20231003_temporal_...
# 3  ../../data/processed/gee_ds_20231003_temporal_...
# 4  ../../data/processed/gee_ds_20231003_temporal_...
#
#                                        features_path        date  ds_type
# 0  ../../data/processed/gee_ds_20231003_temporal_...  2021-11-14   others
# 1  ../../data/processed/gee_ds_20231003_temporal_...  2019-01-28   others
# 2  ../../data/processed/gee_ds_20231003_temporal_...  2023-04-13  current
# 3  ../../data/processed/gee_ds_20231003_temporal_...  2019-02-01   others
# 4  ../../data/processed/gee_ds_20231003_temporal_...  2019-02-05   others

# %%
def load_datasets(df: pd.DataFrame):

    logging.info('Starting...')

    df_curr = df[df['ds_type'] == 'current']
    df_old = df[df['ds_type'] == 'val']

    columns = ['sm_surface', 'precipitationCal', 'volumetric_soil_water_layer_1', 'Optical_Depth_047',
               'evaporation_from_bare_soil_sum',
               'surface_latent_heat_flux_sum', 'Column_WV', 'temperature_2m']
    def _extract_feat_n_targets(base_df, type: str):

        logging.info(f'Extracting {type} dataset.')
        ds = MultiTSDataset(base_df, use_rel=True)

        loader = DataLoader(ds, batch_size=1)

        x_data = []
        target_data = []
        for x, y in loader:
            a = x.squeeze()
            x_data.append(a)
            target_data.append(y.flatten().tolist())

        target = np.array(target_data).flatten()
        features_df = pd.DataFrame(np.concatenate(x_data), columns=columns)
        target_df = pd.DataFrame({'target': target})

        return features_df, target_df

    current_ds = _extract_feat_n_targets(df_curr, 'current')
    old_ds = _extract_feat_n_targets(df_old, 'val')

    logging.info('All datasets loaded correctly.')

    return current_ds, old_ds

# %%
(curr_feats, curr_target), (old_feats, old_target) = load_datasets(df)
# Out:
# 20-Nov-23 18:58:36 - root - INFO - Starting...
# 20-Nov-23 18:58:36 - root - INFO - Extracting current dataset.
# 20-Nov-23 18:58:36 - root - INFO - Extracting val dataset.
# 20-Nov-23 18:58:38 - root - INFO - All datasets loaded correctly.

# %%
curr_feats.head()
# Out:
#    sm_surface  precipitationCal  volumetric_soil_water_layer_1
# 0    1.245891          0.991005                       0.971815  \
# 1    1.366299          1.440902                       0.997121
# 2    1.360401         -0.341436                       1.023707
# 3    1.382988          0.017002                       0.975043
# 4    1.365270          1.087744                       1.076559
#
#    Optical_Depth_047  evaporation_from_bare_soil_sum
# 0          -0.352630                       -0.233975  \
# 1          -0.100061                        1.317170
# 2          -0.100061                        0.766852
# 3          -0.100061                        1.301290
# 4          -0.100061                        0.731486
#
#    surface_latent_heat_flux_sum  Column_WV  temperature_2m
# 0                     -0.896474   0.704385       -0.417923
# 1                      0.006891  -2.505527       -0.871619
# 2                     -0.227956   0.002070       -0.807393
# 3                      0.183847  -1.367084       -1.131056
# 4                      0.376179   0.002070       -1.179700

# %%
curr_target.head()
# Out:
#       target
# 0   4.221332
# 1  -1.539109
# 2   9.283604
# 3   5.637645
# 4  13.495926

# %%
drift_report = Report(metrics=[TargetDriftPreset(stattest='ks', stattest_threshold=0.05)])
 
drift_report.run(reference_data=old_target, current_data=curr_target)

# %%
drift_report.save_json("target_temporal_drift.json", include_render=True)

# %%
drift_report.as_dict()
# Out:
# {'metrics': [{'metric': 'ColumnDriftMetric',
#    'result': {'column_name': 'target',
#     'column_type': 'num',
#     'stattest_name': 'K-S p_value',
#     'stattest_threshold': 0.05,
#     'drift_score': 0.08997219319479635,
#     'drift_detected': False,
#     'current': {'small_distribution': {'x': [-14.52061939239502,
#        -10.854759693145752,
#        -7.188899993896484,
#        -3.523040294647217,
#        0.14281940460205078,
#        3.8086791038513184,
#        7.474538803100586,
#        11.140398502349854,
#        14.806258201599121,
#        18.47211790084839,
#        22.137977600097656],
#       'y': [0.0003007577820395969,
#        0.0015037889101979845,
#        0.003308335602435566,
#        0.005714397858752341,
#        0.04150457392146437,
#        0.10376143480366093,
#        0.0781970233302952,
#        0.02827123151172211,
#        0.00781970233302952,
#        0.002406062256316775]}},
#     'reference': {'small_distribution': {'x': [-18.131059646606445,
#        -12.714060401916504,
#        -7.297061157226562,
#        -1.8800619125366183,
#        3.5369373321533217,
#        8.953936576843262,
#        14.370935821533209,
#        19.78793506622315,
#        25.20493431091309,
#        30.62193355560303,
#        36.03893280029297],
#       'y': [0.00022512689037521797,
#        0.00045025378075043594,
#        0.002926649574877833,
#        0.02712779029021378,
#        0.0959040552998429,
#        0.04401230706835508,
#        0.01046840040244764,
#        0.002588959239315008,
#        0.0007879441163132632,
#        0.00011256344518760904]}}}},
#   {'metric': 'ColumnValuePlot', 'result': {}},
#   {'metric': 'ColumnCorrelationsMetric',
#    'result': {'column_name': 'target', 'current': {}, 'reference': {}}},
#   {'metric': 'TargetByFeaturesTable', 'result': {}}]}

# %%
drift_report = Report(metrics=[DataDriftPreset(stattest='ks', stattest_threshold=0.05)])
 
drift_report.run(reference_data=old_feats, current_data=curr_feats)

# %%
drift_report.save_json("feats_temporal_drift.json", include_render=True)

# %%
drift_report.as_dict()
# Out:
# {'metrics': [{'metric': 'DatasetDriftMetric',
#    'result': {'drift_share': 0.5,
#     'number_of_columns': 8,
#     'number_of_drifted_columns': 8,
#     'share_of_drifted_columns': 1.0,
#     'dataset_drift': True}},
#   {'metric': 'DataDriftTable',
#    'result': {'number_of_columns': 8,
#     'number_of_drifted_columns': 8,
#     'share_of_drifted_columns': 1.0,
#     'dataset_drift': True,
#     'drift_by_columns': {'Column_WV': {'column_name': 'Column_WV',
#       'column_type': 'num',
#       'stattest_name': 'K-S p_value',
#       'stattest_threshold': 0.05,
#       'drift_score': 5.392563058318869e-134,
#       'drift_detected': True,
#       'current': {'small_distribution': {'x': [-2.721226215362549,
#          -2.0933783054351807,
#          -1.4655303955078125,
#          -0.8376824855804443,
#          -0.20983457565307617,
#          0.418013334274292,
#          1.0458612442016602,
#          1.6737091541290283,
#          2.3015570640563965,
#          2.9294049739837646,
#          3.557252883911133],
#         'y': [0.047081534278890044,
#          0.060110023429435125,
#          0.10795171327914722,
#          0.23716372698527327,
#          0.7480291650229597,
#          0.2366922380869153,
#          0.10182476315609731,
#          0.04135150083047822,
#          0.011558694676582191,
#          0.0009790611307739755]}},
#       'reference': {'small_distribution': {'x': [-2.721226215362549,
#          -2.0933783054351807,
#          -1.4655303955078125,
#          -0.8376824855804443,
#          -0.20983457565307617,
#          0.418013334274292,
#          1.0458612442016602,
#          1.6737091541290283,
#          2.3015570640563965,
#          2.9294049739837646,
#          3.557252883911133],
#         'y': [0.05029936973646901,
#          0.060808117132479605,
#          0.10750213107160861,
#          0.23732154756771118,
#          0.7423627145162043,
#          0.24130872517827498,
#          0.10687950874203106,
#          0.03591785823490241,
#          0.009823596755556685,
#          0.0005188519413146137]}}},
#      'Optical_Depth_047': {'column_name': 'Optical_Depth_047',
#       'column_type': 'num',
#       'stattest_name': 'K-S p_value',
#       'stattest_threshold': 0.05,
#       'drift_score': 0.0,
#       'drift_detected': True,
#       'current': {'small_distribution': {'x': [-1.4236207008361816,
#          -0.22588057816028595,
#          0.9718595743179321,
#          2.169599771499634,
#          3.367339849472046,
#          4.565079689025879,
#          5.762820243835449,
#          6.960560321807861,
#          8.158300399780273,
#          9.356040000915527,
#          10.553780555725098],
#         'y': [0.29115335531798336,
#          0.49591458401573557,
#          0.03635649409919113,
#          0.006799189639769447,
#          0.0028132409320884098,
#          0.0011840572199572701,
#          0.00030263455369893683,
#          0.00013618554916452157,
#          0.00017653689327286475,
#          6.935372427864735e-05]}},
#       'reference': {'small_distribution': {'x': [-1.4236207008361816,
#          0.10263161361217499,
#          1.628883957862854,
#          3.1551363468170166,
#          4.6813883781433105,
#          6.207640647888184,
#          7.733893394470215,
#          9.26014518737793,
#          10.786397933959961,
#          12.312649726867676,
#          13.838902473449707],
#         'y': [0.46806497613130654,
#          0.17178795769261995,
#          0.010344623621536757,
#          0.0030598245804780394,
#          0.0011339573493783978,
#          0.00037652626092240545,
#          0.0002216471380210738,
#          0.00017567576999431996,
#          2.13437984761034e-05,
#          1.313463700892112e-05]}}},
#      'evaporation_from_bare_soil_sum': {'column_name': 'evaporation_from_bare_soil_sum',
#       'column_type': 'num',
#       'stattest_name': 'K-S p_value',
#       'stattest_threshold': 0.05,
#       'drift_score': 3.0030337986055088e-58,
#       'drift_detected': True,
#       'current': {'small_distribution': {'x': [-3.284559488296509,
#          -2.7399497032165527,
#          -2.1953399181365967,
#          -1.6507302522659302,
#          -1.1061205863952637,
#          -0.5615108013153076,
#          -0.016901064664125443,
#          0.5277086496353149,
#          1.072318434715271,
#          1.6169281005859375,
#          2.1615378856658936],
#         'y': [0.002939613803217318,
#          0.02867232746364514,
#          0.09940056661500825,
#          0.17519547457904003,
#          0.2593404947374252,
#          0.34518002879005844,
#          0.3916065194180411,
#          0.2888170561661015,
#          0.1328594801046736,
#          0.11216567913672419]}},
#       'reference': {'small_distribution': {'x': [-3.284559488296509,
#          -2.7399497032165527,
#          -2.1953399181365967,
#          -1.6507302522659302,
#          -1.1061205863952637,
#          -0.5615108013153076,
#          -0.016901064664125443,
#          0.5277086496353149,
#          1.072318434715271,
#          1.6169281005859375,
#          2.1615378856658936],
#         'y': [0.003099660758827712,
#          0.02878497433037036,
#          0.08515863515350598,
#          0.1729629486738407,
#          0.26071199096986025,
#          0.34336607009026415,
#          0.38591930965776944,
#          0.30539710537285153,
#          0.14103536226092853,
#          0.10974118090828326]}}},
#      'precipitationCal': {'column_name': 'precipitationCal',
#       'column_type': 'num',
#       'stattest_name': 'K-S p_value',
#       'stattest_threshold': 0.05,
#       'drift_score': 0.0,
#       'drift_detected': True,
#       'current': {'small_distribution': {'x': [-0.5949238538742065,
#          1.3831233978271484,
#          3.361170768737793,
#          5.3392181396484375,
#          7.317265033721924,
#          9.295312881469727,
#          11.273359298706055,
#          13.2514066696167,
#          15.229454040527344,
#          17.207502365112305,
#          19.185548782348633],
#         'y': [0.45580506851503083,
#          0.03768616276587351,
#          0.00850968016746683,
#          0.002349420564145431,
#          0.000642902554844634,
#          0.0003206879671151348,
#          0.00012598449776868794,
#          6.413756250042295e-05,
#          0.0,
#          4.504902395188798e-05]}},
#       'reference': {'small_distribution': {'x': [-0.5949238538742065,
#          1.3831233978271484,
#          3.361170768737793,
#          5.3392181396484375,
#          7.317265033721924,
#          9.295312881469727,
#          11.273359298706055,
#          13.2514066696167,
#          15.229454040527344,
#          17.207502365112305,
#          19.185548782348633],
#         'y': [0.4679331522223533,
#          0.029537797850778678,
#          0.006203659640963983,
#          0.0012360027327193667,
#          0.0003716029656268416,
#          0.0001309056848341499,
#          7.89656492315203e-05,
#          4.3916724706300054e-05,
#          0.0,
#          1.3090568483414988e-05]}}},
#      'sm_surface': {'column_name': 'sm_surface',
#       'column_type': 'num',
#       'stattest_name': 'K-S p_value',
#       'stattest_threshold': 0.05,
#       'drift_score': 0.0,
#       'drift_detected': True,
#       'current': {'small_distribution': {'x': [-2.179370641708374,
#          -1.6863234043121338,
#          -1.1932761669158936,
#          -0.7002289891242981,
#          -0.20718178153038025,
#          0.2858654260635376,
#          0.7789126634597778,
#          1.271959900856018,
#          1.7650070190429688,
#          2.258054256439209,
#          2.751101493835449],
#         'y': [0.04760890881974197,
#          0.16110509210891066,
#          0.2166080020230027,
#          0.26328567497089145,
#          0.3460789876307316,
#          0.37305693994416905,
#          0.279481020073787,
#          0.219582437013421,
#          0.10561139810695172,
#          0.015784886574966565]}},
#       'reference': {'small_distribution': {'x': [-2.1920108795166016,
#          -1.7052185535430908,
#          -1.2184263467788696,
#          -0.7316340208053589,
#          -0.2448417693376541,
#          0.24195051193237305,
#          0.728742778301239,
#          1.215535044670105,
#          1.7023273706436157,
#          2.189119577407837,
#          2.6759119033813477],
#         'y': [0.05407800485654762,
#          0.17251224088382605,
#          0.24764761165522567,
#          0.32117355871357633,
#          0.38336944911988374,
#          0.3639369868788312,
#          0.2493086241811469,
#          0.1846383967695395,
#          0.0662127986554843,
#          0.011386649328215826]}}},
#      'surface_latent_heat_flux_sum': {'column_name': 'surface_latent_heat_flux_sum',
#       'column_type': 'num',
#       'stattest_name': 'K-S p_value',
#       'stattest_threshold': 0.05,
#       'drift_score': 4.152948676159972e-69,
#       'drift_detected': True,
#       'current': {'small_distribution': {'x': [-2.6365342140197754,
#          -2.1253504753112793,
#          -1.6141666173934937,
#          -1.1029828786849976,
#          -0.5917990803718567,
#          -0.08061528205871582,
#          0.43056851625442505,
#          0.9417523145675659,
#          1.452936053276062,
#          1.9641199111938477,
#          2.4753036499023438],
#         'y': [0.0019470550800460352,
#          0.04778999783817693,
#          0.21725471038838398,
#          0.3821693447388552,
#          0.3825652557408344,
#          0.2901584460550043,
#          0.22441062868901196,
#          0.21090240625773307,
#          0.1748271871456325,
#          0.02421852881811434]}},
#       'reference': {'small_distribution': {'x': [-2.6365342140197754,
#          -2.1188018321990967,
#          -1.601069450378418,
#          -1.0833369493484497,
#          -0.565604567527771,
#          -0.047872185707092285,
#          0.4698602259159088,
#          0.9875926375389099,
#          1.5053250789642334,
#          2.023057460784912,
#          2.540789842605591],
#         'y': [0.0015843073996720301,
#          0.0512237881258523,
#          0.21261497208940514,
#          0.37730070987993924,
#          0.3757438293904448,
#          0.28191475632514346,
#          0.2188054360064359,
#          0.21878443729903232,
#          0.17410763915520006,
#          0.019419865753413673]}}},
#      'temperature_2m': {'column_name': 'temperature_2m',
#       'column_type': 'num',
#       'stattest_name': 'K-S p_value',
#       'stattest_threshold': 0.05,
#       'drift_score': 0.0,
#       'drift_detected': True,
#       'current': {'small_distribution': {'x': [-4.187257289886475,
#          -3.452256917953491,
#          -2.7172563076019287,
#          -1.9822559356689453,
#          -1.2472554445266724,
#          -0.5122549533843994,
#          0.22274550795555115,
#          0.9577459692955017,
#          1.6927464008331299,
#          2.4277470111846924,
#          3.162747383117676],
#         'y': [0.00011918189529557216,
#          0.00031850323756038254,
#          0.01617585999597835,
#          0.15234731524283684,
#          0.355459945067199,
#          0.3743810953066924,
#          0.2301607510887466,
#          0.16918279637276168,
#          0.05907926827805521,
#          0.0033185993259025695]}},
#       'reference': {'small_distribution': {'x': [-4.187257289886475,
#          -3.4291844367980957,
#          -2.671111583709717,
#          -1.9130386114120483,
#          -1.1549657583236694,
#          -0.3968929052352905,
#          0.36117997765541077,
#          1.1192528009414673,
#          1.8773257732391357,
#          2.6353986263275146,
#          3.3934714794158936],
#         'y': [3.305549019555567e-05,
#          0.00028427721568177874,
#          0.015050162319352144,
#          0.1515164504093685,
#          0.36432328888966314,
#          0.367815050503987,
#          0.22824595610096549,
#          0.14977219882457707,
#          0.03932060743728665,
#          0.00277335562740712]}}},
#      'volumetric_soil_water_layer_1': {'column_name': 'volumetric_soil_water_layer_1',
#       'column_type': 'num',
#       'stattest_name': 'K-S p_value',
#       'stattest_threshold': 0.05,
#       'drift_score': 7.089187668259015e-106,
#       'drift_detected': True,
#       'current': {'small_distribution': {'x': [-2.4525160789489746,
#          -2.0823075771331787,
#          -1.7120988368988037,
#          -1.3418902158737183,
#          -0.9716816544532776,
#          -0.6014730334281921,
#          -0.23126442730426788,
#          0.13894417881965637,
#          0.5091527700424194,
#          0.8793613910675049,
#          1.2495700120925903],
#         'y': [0.03910757522843378,
#          0.1230627213685119,
#          0.15601412584075913,
#          0.2866406113844521,
#          0.21702535046155697,
#          0.1736463901544394,
#          0.20308109330649934,
#          0.31917583107242775,
#          0.5269321820960798,
#          0.6564938318123821]}},
#       'reference': {'small_distribution': {'x': [-2.490448474884033,
#          -2.1164467334747314,
#          -1.7424447536468506,
#          -1.3684428930282593,
#          -0.9944410920143127,
#          -0.6204392313957214,
#          -0.24643738567829132,
#          0.1275644600391388,
#          0.5015662908554077,
#          0.875568151473999,
#          1.2495700120925903],
#         'y': [0.05174036238501516,
#          0.12419063741678275,
#          0.15724223218214436,
#          0.2699891946099414,
#          0.2253933374151946,
#          0.17219907149873417,
#          0.20848677124727097,
#          0.30653817935543737,
#          0.48487004422123237,
#          0.6731337036256304]}}}},
#     'current_fi': None,
#     'reference_fi': None}}]}
